# %%
import numpy as np
from dataclasses import dataclass

@dataclass
class SplitData:
    """
    A dataclass for representing the result of a data split at a Decision Tree node, including details necessary for propagating splits across the tree.

    Attributes:
        left_partition_mask (np.ndarray): A boolean mask indicating samples allocated to the left child node based on the split.
        right_partition_mask (np.ndarray): A boolean mask indicating samples allocated to the right child node based on the split.
        left_count (int): Number of samples in the left partition, facilitating efficient calculation of statistics or further splits.
        right_count (int): Number of samples in the right partition, facilitating efficient calculation of statistics or further splits.
        feat_index (int): Index of the feature used for splitting, enabling traceability of the decision path within the tree.
        cost (float): The cost or impurity reduction achieved by this split, used to assess the quality of the split.
        thresh (float): Threshold value for the feature at this split, determining the boundary between left and right partitions.
        
    This structure is crucial for the iterative construction and analysis of Decision Trees, where each node's decision to split data affects subsequent nodes' decisions.
    """
    left_partition_mask: np.ndarray
    right_partition_mask: np.ndarray
    left_count: int
    right_count: int 
    feat_index: int 
    cost: float 
    thresh: float

# %%
class TreeNode:
    def __init__(self, 
                    X : np.array, 
                    y : np.array,
                    max_depth=5, 
                    min_leaves=1,
                    depth=0,
                    node_type='init_node',
                    partition=None,
                    
                 ):
        
        self.depth = depth
        self.max_depth = max_depth 
        self.min_leaves = min_leaves

        split_data = self.split_by_min_feat_thresh(X, y, partition)
        
        next_depth = self.depth + 1
        is_not_max_depth = self.max_depth > next_depth        
        left_is_not_max_leaves = min_leaves < split_data.left_count
        right_is_not_max_leaves = min_leaves < split_data.right_count
        
        grow_left = is_not_max_depth and left_is_not_max_leaves
        grow_right = is_not_max_depth and right_is_not_max_leaves

        self.feat_index = split_data.feat_index
        self.thresh = split_data.thresh 

        print(f'[{self.depth}/{self.max_depth}] node_type={node_type}, cost={split_data.cost}, feature_index={split_data.feat_index}, left_count={split_data.left_count}, right_count={split_data.right_count}, thresh={self.thresh}')
        print(f'[{self.depth}/{self.max_depth}] grow_left={grow_left}, grow_right={grow_right}') 
        
        self.left_node = None
        self.right_node = None
        
        if grow_left:
            self.left_node = TreeNode(
                                X, y, 
                                max_depth=max_depth, 
                                min_leaves=min_leaves,
                                depth=next_depth,
                                node_type='left_node',
                                partition=split_data.left_partition_mask
                            )

        if grow_right:
            self.right_node = TreeNode(
                                X,y,
                                max_depth=max_depth,
                                min_leaves=min_leaves,
                                depth=next_depth,
                                node_type='right_node',
                                partition=split_data.right_partition_mask
                            )
    
    def split_by_min_thresh(self, X, y, feat_index, partition_mask=None):
        thresh = np.unique(X[:,feat_index]).reshape(1,-1)
        selected_feat = X[:,feat_index].reshape(-1,1)
        is_left_sampler = (selected_feat <= thresh)
        is_right_sampler = ~is_left_sampler

        if partition_mask is not None:
            partition_mask = np.hstack(is_left_sampler.shape[1] * [ partition_mask.reshape(-1,1) ])
            is_left_sampler = is_left_sampler & partition_mask
            is_right_sampler = is_right_sampler & partition_mask

        stacked_targets = np.hstack([y.reshape(-1,1)] * is_left_sampler.shape[1])
        left_sampled, right_sampled = is_left_sampler * stacked_targets, is_right_sampler * stacked_targets

        n_samples_left, n_samples_right = np.sum(is_left_sampler, axis=0), np.sum(is_right_sampler, axis=0)

        with np.errstate(divide='ignore', invalid='ignore'):
            left_samples_mean = np.where(n_samples_left == 0, 0, np.sum(left_sampled, axis=0) / n_samples_left)
            right_samples_mean = np.where(n_samples_right == 0, 0, np.sum(right_sampled, axis=0) / n_samples_right)
        
        var_left = is_left_sampler * (left_sampled - left_samples_mean.reshape(1,-1)) ** 2
        var_right = is_right_sampler * (right_sampled - right_samples_mean.reshape(1,-1)) ** 2

        with np.errstate(divide='ignore', invalid='ignore'):
            var_left = np.where(n_samples_left == 0, 0, np.sum(var_left, axis=0) / n_samples_left)
            var_right = np.where(n_samples_right == 0, 0, np.sum(var_right, axis=0) / n_samples_right)

        total_samples = left_sampled.shape[0]
        assert total_samples == right_sampled.shape[0], 'wrong total samples'

        ratio_left, ratio_right = n_samples_left / total_samples, n_samples_right / total_samples
        thresh_cost = ratio_left * var_left + ratio_right * var_right
        min_thresh_index = np.argmin(thresh_cost)

        return SplitData(
            left_partition_mask=is_left_sampler[:, min_thresh_index],
            right_partition_mask=is_right_sampler[:, min_thresh_index],
            left_count=np.sum(is_left_sampler[:, min_thresh_index]),
            right_count=np.sum(is_right_sampler[:, min_thresh_index]),
            feat_index=feat_index,
            cost=np.min(thresh_cost),
            thresh=thresh.reshape(-1)[min_thresh_index] 
        )

    def split_by_min_feat_thresh(self, X, y, partition):
        feat_count = X.shape[1]
        min_split_data = self.split_by_min_thresh(X, y, 0)

        for feat_index in range(1, feat_count):
            split_data = self.split_by_min_thresh(X, y, feat_index, partition)
            if min_split_data.cost > split_data.cost:
                min_split_data = split_data

        return min_split_data

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

data = load_diabetes()
X,y = data['data'], data['target']

max_depth = 20
node = TreeNode(X,y, max_depth=20)
# Out:
# [0/20] node_type=init_node, cost=4201.076466066314, feature_index=8, left_count=218, right_count=224, thresh=-0.00422151393810765
# [0/20] grow_left=True, grow_right=True
# [1/20] node_type=left_node, cost=1262.7771702932755, feature_index=2, left_count=171, right_count=47, thresh=0.005649978676881689
# [1/20] grow_left=True, grow_right=True
# [2/20] node_type=left_node, cost=766.8987277935046, feature_index=6, left_count=87, right_count=84, thresh=0.019186997017453092
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=480.77132020228925, feature_index=4, left_count=85, right_count=2, thresh=0.04934129593323023
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=451.91980810847633, feature_index=1, left_count=39, right_count=46, thresh=-0.044641636506989144
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=225.88041370394313, feature_index=3, left_count=21, right_count=18, thresh=-0.03665608107540074
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=89.80368952314653, feature_index=8, left_count=13, right_count=8, thresh=-0.0358161925842373
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=33.18156108597285, feature_index=9, left_count=12, right_count=1, thresh=-0.005219804415300423
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=4.837330316742082, feature_index=9, left_count=2, right_count=10, thresh=-0.07977772888232063
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.07626373893805906
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=2.1724484665661135, feature_index=2, left_count=9, right_count=1, thresh=-0.023450947317899894
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=1.1085972850678734, feature_index=9, left_count=8, right_count=1, thresh=-0.009361911330134878
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.6259426847662142, feature_index=6, left_count=3, right_count=5, thresh=0.0007788079970183853
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.010180995475113122, feature_index=2, left_count=2, right_count=1, thresh=-0.04608500086939666
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06656343027313188
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.04675716440422322, feature_index=3, left_count=2, right_count=3, thresh=-0.07452744180974262
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06764124234701265
# [13/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1, thresh=-0.06332999405148947
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06979686649477428
# [14/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=10.844645550527902, feature_index=3, left_count=6, right_count=2, thresh=-0.05042748497879779
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=3.3003393665158374, feature_index=8, left_count=2, right_count=4, thresh=-0.030747917533098208
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06548561819925106
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.3680241327300151, feature_index=3, left_count=3, right_count=1, thresh=-0.057313186930496314
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.07239819004524888, feature_index=2, left_count=2, right_count=1, thresh=-0.023450947317899894
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.07303030271641665
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05686312160820465
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=89.51040723981897, feature_index=3, left_count=3, right_count=15, thresh=-0.03321323009955148
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.09162895927601811, feature_index=4, left_count=2, right_count=1, thresh=-0.04422349842444599
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05255187331268147
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=70.01438267614738, feature_index=3, left_count=14, right_count=1, thresh=0.07007229917592636
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=53.950226244343895, feature_index=6, left_count=9, right_count=5, thresh=0.008142083605192267
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=15.365384615384617, feature_index=3, left_count=8, right_count=1, thresh=0.0218723855140367
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=8.695324283559579, feature_index=9, left_count=2, right_count=6, thresh=-0.03421455281914162
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.08380842345522464
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=2.1372549019607843, feature_index=8, left_count=3, right_count=3, thresh=-0.03980882652740082
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.11312217194570137, feature_index=2, left_count=2, right_count=1, thresh=-0.010517202431330305
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04608500086939666
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2, thresh=-0.03854031635223107
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03638469220446948
# [13/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=4.891402714932127, feature_index=2, left_count=4, right_count=1, thresh=-0.015906262800734303
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=1.4042232277526396, feature_index=4, left_count=1, right_count=3, thresh=-0.02083229983502694
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2, thresh=-0.06656343027313188
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03746250427835029
# [12/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=163.55196437549378, feature_index=9, left_count=18, right_count=28, thresh=-0.03007244590430716
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=15.179581447963802, feature_index=2, left_count=8, right_count=10, thresh=-0.047162812943277475
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=4.1965093729799605, feature_index=4, left_count=7, right_count=1, thresh=-0.04284754556624487
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=1.2277526395173455, feature_index=8, left_count=4, right_count=3, thresh=-0.06291687914365544
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.22171945701357465, feature_index=2, left_count=1, right_count=3, thresh=-0.07518592686417827
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.004524886877828055, feature_index=3, left_count=1, right_count=2, thresh=-0.04009893205125
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06009655782984706
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.010180995475113122, feature_index=2, left_count=2, right_count=1, thresh=-0.07949717515970146
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.08919748382462865
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=2.5555555555555554, feature_index=2, left_count=9, right_count=1, thresh=-0.010517202431330305
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=1.6580882352941178, feature_index=8, left_count=1, right_count=8, thresh=-0.10163995903077562
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.4543740573152338, feature_index=4, left_count=2, right_count=6, thresh=-0.08137422559587626
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [17/20] grow_left=False, grow_right=True
# [18/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [18/20] grow_left=False, grow_right=True
# [19/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.2234162895927602, feature_index=6, left_count=2, right_count=4, thresh=-0.03235593223976409
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03099563183506548
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.019230769230769232, feature_index=4, left_count=2, right_count=2, thresh=-0.033215875558837024
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04608500086939666
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.035306880130588664
# [12/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=118.29977375565612, feature_index=6, left_count=20, right_count=8, thresh=0.0007788079970183853
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=51.939196832579185, feature_index=6, left_count=8, right_count=12, thresh=-0.024992656631590206
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=9.513009049773757, feature_index=7, left_count=4, right_count=4, thresh=0.012906208769698923
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=5.10633484162896, feature_index=8, left_count=2, right_count=2, thresh=-0.041176166918895155
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.02560657146566148
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03746250427835029
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.16892911010558068, feature_index=3, left_count=1, right_count=3, thresh=-0.06764173985804409
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.01809954751131222, feature_index=2, left_count=1, right_count=2, thresh=-0.02452875939178067
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.018061886948495892
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=20.759049773755656, feature_index=8, left_count=6, right_count=6, thresh=-0.019198449026275908
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.6316742081447965, feature_index=9, left_count=1, right_count=5, thresh=-0.013504018244969336
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.1826923076923077, feature_index=9, left_count=1, right_count=4, thresh=-0.0010776975004659671
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.05542986425339367, feature_index=2, left_count=2, right_count=2, thresh=-0.02560657146566148
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [17/20] grow_left=False, grow_right=True
# [18/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [18/20] grow_left=False, grow_right=True
# [19/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.00943939035744949
# [12/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=7.0, feature_index=6, left_count=3, right_count=3, thresh=-0.01394774321932938
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1, thresh=-0.022373135244019075
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.0320734439089463
# [11/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.01809954751131222, feature_index=2, left_count=1, right_count=2, thresh=-0.029917819761184662
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.0212953231701383
# [11/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=12.279336349924582, feature_index=3, left_count=5, right_count=3, thresh=0.0012152796589411327
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=2.2138009049773757, feature_index=2, left_count=3, right_count=2, thresh=-0.029917819761184662
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.004524886877828055, feature_index=6, left_count=2, right_count=1, thresh=0.01182372140927921
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.07734155101193986
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.028840007687303888
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.40837104072398195, feature_index=2, left_count=2, right_count=1, thresh=-0.01913969902237667
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.02452875939178067
# [9/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [4/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=191.53608597285069, feature_index=1, left_count=64, right_count=20, thresh=-0.044641636506989144
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=157.5469424692954, feature_index=2, left_count=14, right_count=50, thresh=-0.06332999405148947
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=14.475113122171946, feature_index=2, left_count=5, right_count=9, thresh=-0.07734155101193986
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=2.056561085972851, feature_index=2, left_count=4, right_count=1, thresh=-0.08057498723358228
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.3906485671191554, feature_index=4, left_count=3, right_count=1, thresh=-0.035967781275239266
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=2, right_count=1, thresh=-0.08165279930746305
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.08488623552910546
# [9/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=1.7372737556561086, feature_index=3, left_count=1, right_count=8, thresh=-0.10207024961653671
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.84947209653092, feature_index=3, left_count=3, right_count=5, thresh=-0.06877788068007434
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.004524886877828055, feature_index=3, left_count=2, right_count=1, thresh=-0.08141314376144114
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.07303030271641665
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.19457013574660637, feature_index=2, left_count=4, right_count=1, thresh=-0.06656343027313188
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0015082956259426848, feature_index=2, left_count=3, right_count=1, thresh=-0.06979686649477428
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=5, left_count=2, right_count=1, thresh=-0.009142588970957101
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=125.75108408748119, feature_index=3, left_count=48, right_count=2, thresh=0.0218723855140367
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=102.64466539652298, feature_index=2, left_count=38, right_count=10, thresh=-0.01698407487461508
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=81.62503770739066, feature_index=8, left_count=35, right_count=3, thresh=-0.011896851335695978
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=67.01371177841767, feature_index=3, left_count=33, right_count=2, thresh=-0.002227571316908129
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=51.52707390648566, feature_index=3, left_count=30, right_count=3, thresh=-0.012556124244455912
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=25.409592760181, feature_index=4, left_count=5, right_count=25, thresh=-0.05660707414825608
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.9920814479638008, feature_index=4, left_count=2, right_count=3, thresh=-0.07587041416307178
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05470749746044306
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.13687782805429866, feature_index=3, left_count=2, right_count=1, thresh=-0.029770379123702218
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04608500086939666
# [13/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=17.401206636500756, feature_index=6, left_count=19, right_count=6, thresh=0.08545647749101803
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=9.144264040457811, feature_index=6, left_count=17, right_count=2, thresh=0.07809320188284416
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=6.415201879568396, feature_index=3, left_count=4, right_count=13, thresh=-0.05387033595464705
# [13/20] grow_left=True, grow_right=True
# [14/20] node_type=left_node, cost=0.004524886877828054, feature_index=4, left_count=1, right_count=3, thresh=-0.034591828417038145
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=1, right_count=2, thresh=-0.05794093368208547
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04285156464775429
# [16/20] grow_left=False, grow_right=False
# [14/20] node_type=right_node, cost=3.5354449472096525, feature_index=2, left_count=1, right_count=12, thresh=-0.06225218197760866
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=2.3044014808720696, feature_index=9, left_count=11, right_count=1, thresh=0.0113486232440374
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=1.5260180995475112, feature_index=7, left_count=2, right_count=9, thresh=-0.0763945037500033
# [16/20] grow_left=True, grow_right=True
# [17/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.061174369903727877
# [17/20] grow_left=False, grow_right=False
# [17/20] node_type=right_node, cost=0.8733031674208145, feature_index=9, left_count=6, right_count=3, thresh=-0.03835665973397607
# [17/20] grow_left=True, grow_right=True
# [18/20] node_type=left_node, cost=0.1657239819004525, feature_index=6, left_count=4, right_count=2, thresh=0.07072992627467027
# [18/20] grow_left=True, grow_right=True
# [19/20] node_type=left_node, cost=0.005656108597285069, feature_index=4, left_count=2, right_count=2, thresh=-0.00019300696201012598
# [19/20] grow_left=False, grow_right=False
# [19/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.051474061238800654
# [19/20] grow_left=False, grow_right=False
# [18/20] node_type=right_node, cost=0.0, feature_index=2, left_count=2, right_count=1, thresh=-0.040695940499992665
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.049318437091039065
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.5096153846153847, feature_index=2, left_count=4, right_count=2, thresh=-0.033151255982827074
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=0.1644042232277526, feature_index=6, left_count=1, right_count=3, thresh=0.10018302870736581
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2, thresh=-0.06009655782984706
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05470749746044306
# [15/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.0320734439089463
# [13/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.49886877828054305, feature_index=3, left_count=2, right_count=1, thresh=-0.0079771324465764
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05794093368208547
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05901874575596628
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.4524886877828055, feature_index=3, left_count=1, right_count=2, thresh=-0.05387033595464705
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.020217511096257485
# [9/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=7.018288084464555, feature_index=8, left_count=6, right_count=4, thresh=-0.041176166918895155
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.179185520361991, feature_index=4, left_count=5, right_count=1, thresh=0.019070333052805567
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.41855203619909503, feature_index=2, left_count=1, right_count=4, thresh=-0.008361578283568675
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.08597285067873303, feature_index=3, left_count=3, right_count=1, thresh=-0.009113273268606652
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0011312217194570137, feature_index=5, left_count=2, right_count=1, thresh=0.006827982580309182
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.004050329988045492
# [12/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.7070135746606335, feature_index=4, left_count=2, right_count=2, thresh=0.010814615903598841
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.004050329988045492
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.041773752573873474
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=14.3897328162034, feature_index=3, left_count=6, right_count=14, thresh=-0.029770379123702218
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.1855203619909502, feature_index=2, left_count=1, right_count=5, thresh=-0.07195249064253588
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.032805429864253395, feature_index=2, left_count=2, right_count=3, thresh=-0.020217511096257485
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.040695940499992665
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=1, right_count=2, thresh=-0.015906262800734303
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.007283766209687899
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=6.918552036199094, feature_index=2, left_count=3, right_count=11, thresh=-0.05578530953432388
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.04072398190045249, feature_index=3, left_count=2, right_count=1, thresh=0.011543832586488917
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06225218197760866
# [7/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=3.2870789341377575, feature_index=6, left_count=9, right_count=2, thresh=0.04127682384197474
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=1.3755656108597287, feature_index=4, left_count=1, right_count=8, thresh=-0.04972730985725048
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.5282051282051281, feature_index=9, left_count=5, right_count=3, thresh=-0.01764612515980379
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.09671945701357466, feature_index=9, left_count=1, right_count=4, thresh=-0.05906719430814835
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.028657616892911013, feature_index=6, left_count=1, right_count=3, thresh=0.026550272625626974
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1, thresh=-0.041773752573873474
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04608500086939666
# [12/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=2, right_count=1, thresh=-0.02452875939178067
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03099563183506548
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04500718879551588
# [7/20] grow_left=False, grow_right=False
# [2/20] node_type=right_node, cost=387.6068088773971, feature_index=8, left_count=12, right_count=35, thresh=-0.04688253415273158
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=43.88612368024133, feature_index=7, left_count=6, right_count=6, thresh=-0.021411833644897377
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=3.1889140271493215, feature_index=7, left_count=4, right_count=2, thresh=-0.03949338287409329
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.40723981900452494, feature_index=3, left_count=2, right_count=2, thresh=-0.02632752814785296
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.05415152200151766
# [6/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.018583723563451313
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.026128408080616904
# [5/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=9.009049773755656, feature_index=5, left_count=5, right_count=1, thresh=0.04252690722431616
# [4/20] grow_left=True, grow_right=False
# [5/20] node_type=left_node, cost=4.665158371040723, feature_index=7, left_count=3, right_count=2, thresh=0.0003598276718895252
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0011312217194570137, feature_index=1, left_count=2, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.015350287341808908
# [7/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.04984027370599448
# [6/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=280.9234539969834, feature_index=3, left_count=27, right_count=8, thresh=0.04252949136913227
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=194.18354383173386, feature_index=2, left_count=13, right_count=14, thresh=0.03582871674554409
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=59.095588235294116, feature_index=8, left_count=12, right_count=1, thresh=-0.015998872510179042
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=44.55697243932537, feature_index=5, left_count=11, right_count=1, thresh=0.04722413415115918
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=23.70135746606335, feature_index=5, left_count=8, right_count=3, thresh=0.017788178742942903
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=7.986425339366516, feature_index=3, left_count=4, right_count=4, thresh=-0.0228846771720037
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.1870286576168929, feature_index=7, left_count=1, right_count=3, thresh=-0.03949338287409329
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.004524886877828055, feature_index=3, left_count=1, right_count=2, thresh=-0.07452744180974262
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.006727790750762504
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.09502262443438914, feature_index=2, left_count=3, right_count=1, thresh=0.023972783932855315
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.010180995475113122, feature_index=2, left_count=1, right_count=2, thresh=0.008883414898524095
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=1, right_count=2, thresh=0.014272475267928093
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [9/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=68.31711915535446, feature_index=2, left_count=12, right_count=2, thresh=0.06492964274032566
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=28.5359477124183, feature_index=1, left_count=9, right_count=3, thresh=-0.044641636506989144
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=9.895927601809953, feature_index=5, left_count=3, right_count=6, thresh=-0.016658152053905938
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.028280542986425343, feature_index=3, left_count=2, right_count=1, thresh=-0.04009893205125
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.0369065288194249
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=2.015082956259427, feature_index=4, left_count=3, right_count=3, thresh=-0.009824676969417972
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.36651583710407243, feature_index=2, left_count=1, right_count=2, thresh=0.03798434089330568
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.04013996504106731
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.04072398190045249, feature_index=3, left_count=1, right_count=2, thresh=-0.05617704610846606
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.04337340126270967
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.13687782805429866, feature_index=2, left_count=2, right_count=1, thresh=0.05415152200151766
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.04121777711494808
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.07031870310972965
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=35.97254901960784, feature_index=2, left_count=3, right_count=5, thresh=0.045529025410471304
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.010180995475113122, feature_index=4, left_count=1, right_count=2, thresh=-0.12678066991651324
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=1.9276018099547514, feature_index=9, left_count=4, right_count=1, thresh=0.036201264733044136
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.04223227752639517, feature_index=2, left_count=1, right_count=3, thresh=0.05415152200151766
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.004524886877828055, feature_index=1, left_count=2, right_count=1, thresh=-0.044641636506989144
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.08001901177465684
# [8/20] grow_left=False, grow_right=False
# [1/20] node_type=right_node, cost=2097.272926382459, feature_index=2, left_count=116, right_count=108, thresh=0.014272475267928093
# [1/20] grow_left=True, grow_right=True
# [2/20] node_type=left_node, cost=981.8996037084273, feature_index=2, left_count=42, right_count=74, thresh=-0.022373135244019075
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=222.74849170437403, feature_index=4, left_count=6, right_count=36, thresh=-0.05385516843185383
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=16.553544494720967, feature_index=5, left_count=3, right_count=3, thresh=-0.07051968748170592
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.05542986425339367, feature_index=2, left_count=2, right_count=1, thresh=-0.041773752573873474
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=2, left_count=2, right_count=1, thresh=-0.02560657146566148
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=163.66923076923075, feature_index=9, left_count=30, right_count=6, thresh=0.040343371647878594
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=124.37908496732025, feature_index=8, left_count=21, right_count=9, thresh=0.02671684132010462
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=58.49337427278603, feature_index=2, left_count=7, right_count=14, thresh=-0.05794093368208547
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=18.332126696832578, feature_index=6, left_count=2, right_count=5, thresh=-0.04340084565202491
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06548561819925106
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.47322775263951733, feature_index=6, left_count=3, right_count=2, thresh=-0.006584467611155497
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.010180995475113122, feature_index=1, left_count=2, right_count=1, thresh=-0.044641636506989144
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06440780612537028
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.06548561819925106
# [9/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=18.897220426632195, feature_index=5, left_count=7, right_count=7, thresh=-0.0010007289644291908
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=2.758371040723982, feature_index=8, left_count=5, right_count=2, thresh=0.019196469166885697
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.8506787330316743, feature_index=6, left_count=2, right_count=3, thresh=-0.02131101882750326
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03099563183506548
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.07239819004524888, feature_index=2, left_count=1, right_count=2, thresh=-0.029917819761184662
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.03099563183506548
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=5.506033182503771, feature_index=5, left_count=3, right_count=4, thresh=0.01622243643399523
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=1.0180995475113124, feature_index=4, left_count=1, right_count=2, thresh=-0.015328488402222454
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.37254901960784315, feature_index=2, left_count=3, right_count=1, thresh=-0.033151255982827074
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.05542986425339367, feature_index=3, left_count=1, right_count=2, thresh=-0.0848559947372904
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.039618128426111884
# [11/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=15.718164188752423, feature_index=6, left_count=7, right_count=2, thresh=0.033913548233800855
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=5.527828054298642, feature_index=8, left_count=5, right_count=2, thresh=0.06605066658209234
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.5094268476621417, feature_index=2, left_count=3, right_count=2, thresh=-0.027762195613423073
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2, thresh=-0.050396249164919873
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.02560657146566148
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.05578530953432388
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.04500718879551588
# [7/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=2.083257918552036, feature_index=8, left_count=5, right_count=1, thresh=0.031192602201596156
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.5625942684766214, feature_index=2, left_count=3, right_count=2, thresh=-0.03422906805670789
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2, thresh=-0.03854031635223107
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=-0.033151255982827074
# [7/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=635.8776619622208, feature_index=8, left_count=18, right_count=56, thresh=0.014073500500086794
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=81.30066132962061, feature_index=6, left_count=5, right_count=13, thresh=-0.04708248345611185
# [4/20] grow_left=True, grow_right=True
# ...
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.9971719457013575, feature_index=2, left_count=2, right_count=4, thresh=0.039062152967186486
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.058823529411764705, feature_index=4, left_count=3, right_count=1, thresh=0.05759701308243695
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.004524886877828055, feature_index=4, left_count=2, right_count=1, thresh=0.045213437358626866
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [14/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [11/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=6.523190045248869, feature_index=4, left_count=2, right_count=4, thresh=0.039709625925822375
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.0422955891888289
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.2907239819004525, feature_index=1, left_count=2, right_count=2, thresh=-0.044641636506989144
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.030439656376140087
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.03475090467166331
# [12/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=12.29110105580694, feature_index=2, left_count=3, right_count=2, thresh=0.039062152967186486
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.5486425339366516, feature_index=2, left_count=2, right_count=1, thresh=0.027206220154497678
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.01966153563733209
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.05415152200151766
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=3, left_count=1, right_count=2, thresh=-0.04698463400294853
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=161.62965057817996, feature_index=8, left_count=36, right_count=8, thresh=0.07379892880056037
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=120.58286199095024, feature_index=3, left_count=32, right_count=4, thresh=0.0941722560068712
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=104.45446107437058, feature_index=9, left_count=6, right_count=26, thresh=-0.021788232074638245
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=1.3642533936651584, feature_index=6, left_count=4, right_count=2, thresh=0.022868634821540033
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.18099547511312217, feature_index=1, left_count=2, right_count=2, thresh=-0.044641636506989144
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.018583723563451313
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.016428099415689682
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.022894971858974496
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=87.02393599580299, feature_index=2, left_count=3, right_count=23, thresh=0.0175059114895705
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.3076923076923077, feature_index=2, left_count=1, right_count=2, thresh=0.016428099415689682
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=71.83021390374333, feature_index=9, left_count=22, right_count=1, thresh=0.05691179930721642
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=62.969645550527915, feature_index=9, left_count=16, right_count=6, thresh=0.036201264733044136
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=39.97948717948718, feature_index=5, left_count=1, right_count=15, thresh=-0.048912443618228024
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=26.549490950226247, feature_index=5, left_count=7, right_count=8, thresh=0.0071411310420987206
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=3.0245098039215685, feature_index=2, left_count=6, right_count=1, thresh=0.045529025410471304
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=1.2126696832579185, feature_index=4, left_count=5, right_count=1, thresh=0.013566521620001083
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.1917420814479638, feature_index=2, left_count=1, right_count=4, thresh=0.01966153563733209
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.05429864253393665, feature_index=3, left_count=3, right_count=1, thresh=0.08384370307932341
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=4, left_count=1, right_count=2, thresh=-0.04009563984984263
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [17/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=7.7007918552036205, feature_index=4, left_count=4, right_count=4, thresh=0.020446285911006685
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=1.431372549019608, feature_index=2, left_count=3, right_count=1, thresh=0.022894971858974496
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2, thresh=0.018583723563451313
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.01966153563733209
# [15/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.6892911010558068, feature_index=5, left_count=1, right_count=3, thresh=0.019667069513680118
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.05542986425339367, feature_index=3, left_count=1, right_count=2, thresh=0.03333707926361473
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [15/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=2.995475113122172, feature_index=2, left_count=5, right_count=1, thresh=0.04768464955823289
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.7782805429864255, feature_index=2, left_count=1, right_count=4, thresh=0.020739347711212906
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.1870286576168929, feature_index=3, left_count=1, right_count=3, thresh=0.029894228287765473
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1, thresh=0.039062152967186486
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [14/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.7782805429864253, feature_index=1, left_count=3, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.11312217194570137, feature_index=2, left_count=1, right_count=2, thresh=0.031517468450020895
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.03367309259778249
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=5.780995475113121, feature_index=6, left_count=5, right_count=3, thresh=-0.03971920784793797
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=1.1063348416289593, feature_index=2, left_count=1, right_count=4, thresh=0.018583723563451313
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.20135746606334842, feature_index=3, left_count=2, right_count=2, thresh=0.06205045640219759
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.06061839444480248
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.05542986425339367, feature_index=2, left_count=1, right_count=2, thresh=0.045529025410471304
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [7/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=98.02914384377232, feature_index=5, left_count=19, right_count=12, thresh=0.02154596028441731
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=29.927090066795948, feature_index=8, left_count=7, right_count=12, thresh=0.02993464904142137
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=1.0119909502262443, feature_index=6, left_count=5, right_count=2, thresh=-0.02131101882750326
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.25, feature_index=2, left_count=2, right_count=3, thresh=0.10480868947391528
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.07678557555301448
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.028280542986425343, feature_index=1, left_count=1, right_count=2, thresh=-0.044641636506989144
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.11127556191720007
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=6.476347182229536, feature_index=7, left_count=11, right_count=1, thresh=0.03430885887772673
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=1.2356711915535445, feature_index=5, left_count=8, right_count=3, thresh=-0.002253322811587326
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.6998491704374056, feature_index=9, left_count=2, right_count=6, thresh=0.019632837073706312
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.07462995140525285
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.08880090497737558, feature_index=5, left_count=2, right_count=4, thresh=-0.032002426681593144
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.006033182503770739, feature_index=2, left_count=3, right_count=1, thresh=0.09726400495674965
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=1, thresh=-0.044641636506989144
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0, thresh=-0.044641636506989144
# [19/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=1, right_count=2, thresh=0.07139651518361048
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.08864150836570328
# [8/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=23.75277663512957, feature_index=4, left_count=1, right_count=11, thresh=0.014942474478202204
# [4/20] grow_left=False, grow_right=True
# [5/20] node_type=right_node, cost=14.32601809954751, feature_index=6, left_count=1, right_count=10, thresh=-0.06180903467245962
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=8.091628959276019, feature_index=4, left_count=2, right_count=8, thresh=0.02182223876920781
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=3.916742081447964, feature_index=9, left_count=5, right_count=3, thresh=0.040343371647878594
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.14649321266968326, feature_index=2, left_count=1, right_count=4, thresh=0.07139651518361048
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.019230769230769232, feature_index=6, left_count=2, right_count=2, thresh=-0.02131101882750326
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.09834181703063047
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1, thresh=-0.044641636506989144
# [10/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.1911764705882353, feature_index=3, left_count=2, right_count=1, thresh=-0.015998975220305175
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1, thresh=0.07139651518361048
# [9/20] grow_left=False, grow_right=False
