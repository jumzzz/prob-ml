# %%
import numpy as np
from dataclasses import dataclass

@dataclass
class SplitData:
    """
    A dataclass for representing the result of a data split at a Decision Tree node, including details necessary for propagating splits across the tree.

    Attributes:
        left_partition_mask (np.ndarray): A boolean mask indicating samples allocated to the left child node based on the split.
        right_partition_mask (np.ndarray): A boolean mask indicating samples allocated to the right child node based on the split.
        left_count (int): Number of samples in the left partition, facilitating efficient calculation of statistics or further splits.
        right_count (int): Number of samples in the right partition, facilitating efficient calculation of statistics or further splits.
        feat_index (int): Index of the feature used for splitting, enabling traceability of the decision path within the tree.
        cost (float): The cost or impurity reduction achieved by this split, used to assess the quality of the split.
        thresh (float): Threshold value for the feature at this split, determining the boundary between left and right partitions.
        
    This structure is crucial for the iterative construction and analysis of Decision Trees, where each node's decision to split data affects subsequent nodes' decisions.
    """
    left_partition_mask: np.ndarray
    right_partition_mask: np.ndarray
    left_count: int
    right_count: int 
    feat_index: int 
    cost: float 
    thresh: float

# %%
class TreeNode:
    def __init__(self, 
                    X : np.array, 
                    y : np.array,
                    max_depth=5, 
                    min_leaves=1,
                    depth=0,
                    node_type='init_node',
                    partition=None,
                    
                 ):
        
        self.depth = depth
        self.max_depth = max_depth 
        self.min_leaves = min_leaves

        split_data = self.split_by_min_feat_thresh(X, y, partition)
        
        next_depth = self.depth + 1
        is_not_max_depth = self.max_depth > next_depth        
        left_is_not_max_leaves = min_leaves < split_data.left_count
        right_is_not_max_leaves = min_leaves < split_data.right_count
        
        grow_left = is_not_max_depth and left_is_not_max_leaves
        grow_right = is_not_max_depth and right_is_not_max_leaves


        print(f'[{self.depth}/{self.max_depth}] node_type={node_type}, cost={split_data.cost}, feature_index={split_data.feat_index}, left_count={split_data.left_count}, right_count={split_data.right_count}')
        print(f'[{self.depth}/{self.max_depth}] grow_left={grow_left}, grow_right={grow_right}') 
        if grow_left:
            self.left_node = TreeNode(
                                X, y, 
                                max_depth=max_depth, 
                                min_leaves=min_leaves,
                                depth=next_depth,
                                node_type='left_node',
                                partition=split_data.left_partition_mask
                            )

        if grow_right:
            self.right_node = TreeNode(
                                X,y,
                                max_depth=max_depth,
                                min_leaves=min_leaves,
                                depth=next_depth,
                                node_type='right_node',
                                partition=split_data.right_partition_mask
                            )
    
    def split_by_min_thresh(self, X, y, feat_index, partition_mask=None):
        thresh = np.unique(X[:,feat_index]).reshape(1,-1)
        selected_feat = X[:,feat_index].reshape(-1,1)
        is_left_sampler = (selected_feat <= thresh)
        is_right_sampler = ~is_left_sampler

        if partition_mask is not None:
            partition_mask = np.hstack(is_left_sampler.shape[1] * [ partition_mask.reshape(-1,1) ])
            is_left_sampler = is_left_sampler & partition_mask
            is_right_sampler = is_right_sampler & partition_mask

        stacked_targets = np.hstack([y.reshape(-1,1)] * is_left_sampler.shape[1])
        left_sampled, right_sampled = is_left_sampler * stacked_targets, is_right_sampler * stacked_targets

        n_samples_left, n_samples_right = np.sum(is_left_sampler, axis=0), np.sum(is_right_sampler, axis=0)

        with np.errstate(divide='ignore', invalid='ignore'):
            left_samples_mean = np.where(n_samples_left == 0, 0, np.sum(left_sampled, axis=0) / n_samples_left)
            right_samples_mean = np.where(n_samples_right == 0, 0, np.sum(right_sampled, axis=0) / n_samples_right)
        
        var_left = is_left_sampler * (left_sampled - left_samples_mean.reshape(1,-1)) ** 2
        var_right = is_right_sampler * (right_sampled - right_samples_mean.reshape(1,-1)) ** 2

        with np.errstate(divide='ignore', invalid='ignore'):
            var_left = np.where(n_samples_left == 0, 0, np.sum(var_left, axis=0) / n_samples_left)
            var_right = np.where(n_samples_right == 0, 0, np.sum(var_right, axis=0) / n_samples_right)

        total_samples = left_sampled.shape[0]
        assert total_samples == right_sampled.shape[0], 'wrong total samples'

        ratio_left, ratio_right = n_samples_left / total_samples, n_samples_right / total_samples
        thresh_cost = ratio_left * var_left + ratio_right * var_right
        min_thresh_index = np.argmin(thresh_cost)

        return SplitData(
            left_partition_mask=is_left_sampler[:, min_thresh_index],
            right_partition_mask=is_right_sampler[:, min_thresh_index],
            left_count=np.sum(is_left_sampler[:, min_thresh_index]),
            right_count=np.sum(is_right_sampler[:, min_thresh_index]),
            feat_index=feat_index,
            cost=np.min(thresh_cost),
            thresh=thresh.reshape(-1)[min_thresh_index] 
        )

    def split_by_min_feat_thresh(self, X, y, partition):
        feat_count = X.shape[1]
        min_split_data = self.split_by_min_thresh(X, y, 0)

        for feat_index in range(1, feat_count):
            split_data = self.split_by_min_thresh(X, y, feat_index, partition)
            if min_split_data.cost > split_data.cost:
                min_split_data = split_data

        return min_split_data

# %%
from sklearn.datasets import load_diabetes
import pandas as pd

data = load_diabetes()
X,y = data['data'], data['target']

max_depth = 20
node = TreeNode(X,y, max_depth=20)
# Out:
# [0/20] node_type=init_node, cost=4201.076466066314, feature_index=8, left_count=218, right_count=224
# [0/20] grow_left=True, grow_right=True
# [1/20] node_type=left_node, cost=1262.7771702932755, feature_index=2, left_count=171, right_count=47
# [1/20] grow_left=True, grow_right=True
# [2/20] node_type=left_node, cost=766.8987277935046, feature_index=6, left_count=87, right_count=84
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=480.77132020228925, feature_index=4, left_count=85, right_count=2
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=451.91980810847633, feature_index=1, left_count=39, right_count=46
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=225.88041370394313, feature_index=3, left_count=21, right_count=18
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=89.80368952314653, feature_index=8, left_count=13, right_count=8
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=33.18156108597285, feature_index=9, left_count=12, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=4.837330316742082, feature_index=9, left_count=2, right_count=10
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=2.1724484665661135, feature_index=2, left_count=9, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=1.1085972850678734, feature_index=9, left_count=8, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.6259426847662142, feature_index=6, left_count=3, right_count=5
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.010180995475113122, feature_index=2, left_count=2, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.04675716440422322, feature_index=3, left_count=2, right_count=3
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [14/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=10.844645550527902, feature_index=3, left_count=6, right_count=2
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=3.3003393665158374, feature_index=8, left_count=2, right_count=4
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.3680241327300151, feature_index=3, left_count=3, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.07239819004524888, feature_index=2, left_count=2, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=89.51040723981897, feature_index=3, left_count=3, right_count=15
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.09162895927601811, feature_index=4, left_count=2, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=70.01438267614738, feature_index=3, left_count=14, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=53.950226244343895, feature_index=6, left_count=9, right_count=5
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=15.365384615384617, feature_index=3, left_count=8, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=8.695324283559579, feature_index=9, left_count=2, right_count=6
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=2.1372549019607843, feature_index=8, left_count=3, right_count=3
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.11312217194570137, feature_index=2, left_count=2, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=4.891402714932127, feature_index=2, left_count=4, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=1.4042232277526396, feature_index=4, left_count=1, right_count=3
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=163.55196437549378, feature_index=9, left_count=18, right_count=28
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=15.179581447963802, feature_index=2, left_count=8, right_count=10
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=4.1965093729799605, feature_index=4, left_count=7, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=1.2277526395173455, feature_index=8, left_count=4, right_count=3
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.22171945701357465, feature_index=2, left_count=1, right_count=3
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.004524886877828055, feature_index=3, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.010180995475113122, feature_index=2, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=2.5555555555555554, feature_index=2, left_count=9, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=1.6580882352941178, feature_index=8, left_count=1, right_count=8
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.4543740573152338, feature_index=4, left_count=2, right_count=6
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [17/20] grow_left=False, grow_right=True
# [18/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [18/20] grow_left=False, grow_right=True
# [19/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [19/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.2234162895927602, feature_index=6, left_count=2, right_count=4
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.019230769230769232, feature_index=4, left_count=2, right_count=2
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=118.29977375565612, feature_index=6, left_count=20, right_count=8
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=51.939196832579185, feature_index=6, left_count=8, right_count=12
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=9.513009049773757, feature_index=7, left_count=4, right_count=4
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=5.10633484162896, feature_index=8, left_count=2, right_count=2
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.16892911010558068, feature_index=3, left_count=1, right_count=3
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.01809954751131222, feature_index=2, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=20.759049773755656, feature_index=8, left_count=6, right_count=6
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.6316742081447965, feature_index=9, left_count=1, right_count=5
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.1826923076923077, feature_index=9, left_count=1, right_count=4
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.05542986425339367, feature_index=2, left_count=2, right_count=2
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [17/20] grow_left=False, grow_right=True
# [18/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [18/20] grow_left=False, grow_right=True
# [19/20] node_type=right_node, cost=0.0, feature_index=1, left_count=0, right_count=2
# [19/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=7.0, feature_index=6, left_count=3, right_count=3
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.01809954751131222, feature_index=2, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=12.279336349924582, feature_index=3, left_count=5, right_count=3
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=2.2138009049773757, feature_index=2, left_count=3, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.004524886877828055, feature_index=6, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.40837104072398195, feature_index=2, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [4/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=191.53608597285069, feature_index=1, left_count=64, right_count=20
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=157.5469424692954, feature_index=2, left_count=14, right_count=50
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=14.475113122171946, feature_index=2, left_count=5, right_count=9
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=2.056561085972851, feature_index=2, left_count=4, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.3906485671191554, feature_index=4, left_count=3, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=1.7372737556561086, feature_index=3, left_count=1, right_count=8
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.84947209653092, feature_index=3, left_count=3, right_count=5
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.004524886877828055, feature_index=3, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.19457013574660637, feature_index=2, left_count=4, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0015082956259426848, feature_index=2, left_count=3, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=5, left_count=2, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [19/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=125.75108408748119, feature_index=3, left_count=48, right_count=2
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=102.64466539652298, feature_index=2, left_count=38, right_count=10
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=81.62503770739066, feature_index=8, left_count=35, right_count=3
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=67.01371177841767, feature_index=3, left_count=33, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=51.52707390648566, feature_index=3, left_count=30, right_count=3
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=25.409592760181, feature_index=4, left_count=5, right_count=25
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.9920814479638008, feature_index=4, left_count=2, right_count=3
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.13687782805429866, feature_index=3, left_count=2, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=17.401206636500756, feature_index=6, left_count=19, right_count=6
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=9.144264040457811, feature_index=6, left_count=17, right_count=2
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=6.415201879568396, feature_index=3, left_count=4, right_count=13
# [13/20] grow_left=True, grow_right=True
# [14/20] node_type=left_node, cost=0.004524886877828054, feature_index=4, left_count=1, right_count=3
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=1, right_count=2
# [15/20] grow_left=False, grow_right=True
# [16/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [16/20] grow_left=False, grow_right=False
# [14/20] node_type=right_node, cost=3.5354449472096525, feature_index=2, left_count=1, right_count=12
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=2.3044014808720696, feature_index=9, left_count=11, right_count=1
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=1.5260180995475112, feature_index=7, left_count=2, right_count=9
# [16/20] grow_left=True, grow_right=True
# [17/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [17/20] grow_left=False, grow_right=False
# [17/20] node_type=right_node, cost=0.8733031674208145, feature_index=9, left_count=6, right_count=3
# [17/20] grow_left=True, grow_right=True
# [18/20] node_type=left_node, cost=0.1657239819004525, feature_index=6, left_count=4, right_count=2
# [18/20] grow_left=True, grow_right=True
# [19/20] node_type=left_node, cost=0.005656108597285069, feature_index=4, left_count=2, right_count=2
# [19/20] grow_left=False, grow_right=False
# [19/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [19/20] grow_left=False, grow_right=False
# [18/20] node_type=right_node, cost=0.0, feature_index=2, left_count=2, right_count=1
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [19/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.5096153846153847, feature_index=2, left_count=4, right_count=2
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=0.1644042232277526, feature_index=6, left_count=1, right_count=3
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [15/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.49886877828054305, feature_index=3, left_count=2, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.4524886877828055, feature_index=3, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=7.018288084464555, feature_index=8, left_count=6, right_count=4
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.179185520361991, feature_index=4, left_count=5, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.41855203619909503, feature_index=2, left_count=1, right_count=4
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.08597285067873303, feature_index=3, left_count=3, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0011312217194570137, feature_index=5, left_count=2, right_count=1
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.7070135746606335, feature_index=4, left_count=2, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [19/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=14.3897328162034, feature_index=3, left_count=6, right_count=14
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.1855203619909502, feature_index=2, left_count=1, right_count=5
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.032805429864253395, feature_index=2, left_count=2, right_count=3
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=6.918552036199094, feature_index=2, left_count=3, right_count=11
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.04072398190045249, feature_index=3, left_count=2, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=3.2870789341377575, feature_index=6, left_count=9, right_count=2
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=1.3755656108597287, feature_index=4, left_count=1, right_count=8
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.5282051282051281, feature_index=9, left_count=5, right_count=3
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.09671945701357466, feature_index=9, left_count=1, right_count=4
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.028657616892911013, feature_index=6, left_count=1, right_count=3
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [2/20] node_type=right_node, cost=387.6068088773971, feature_index=8, left_count=12, right_count=35
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=43.88612368024133, feature_index=7, left_count=6, right_count=6
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=3.1889140271493215, feature_index=7, left_count=4, right_count=2
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.40723981900452494, feature_index=3, left_count=2, right_count=2
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [5/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=9.009049773755656, feature_index=5, left_count=5, right_count=1
# [4/20] grow_left=True, grow_right=False
# [5/20] node_type=left_node, cost=4.665158371040723, feature_index=7, left_count=3, right_count=2
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0011312217194570137, feature_index=1, left_count=2, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=280.9234539969834, feature_index=3, left_count=27, right_count=8
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=194.18354383173386, feature_index=2, left_count=13, right_count=14
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=59.095588235294116, feature_index=8, left_count=12, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=44.55697243932537, feature_index=5, left_count=11, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=23.70135746606335, feature_index=5, left_count=8, right_count=3
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=7.986425339366516, feature_index=3, left_count=4, right_count=4
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.1870286576168929, feature_index=7, left_count=1, right_count=3
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.004524886877828055, feature_index=3, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.09502262443438914, feature_index=2, left_count=3, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.010180995475113122, feature_index=2, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=68.31711915535446, feature_index=2, left_count=12, right_count=2
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=28.5359477124183, feature_index=1, left_count=9, right_count=3
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=9.895927601809953, feature_index=5, left_count=3, right_count=6
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.028280542986425343, feature_index=3, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=2.015082956259427, feature_index=4, left_count=3, right_count=3
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.36651583710407243, feature_index=2, left_count=1, right_count=2
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.04072398190045249, feature_index=3, left_count=1, right_count=2
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.13687782805429866, feature_index=2, left_count=2, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=35.97254901960784, feature_index=2, left_count=3, right_count=5
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.010180995475113122, feature_index=4, left_count=1, right_count=2
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=1.9276018099547514, feature_index=9, left_count=4, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.04223227752639517, feature_index=2, left_count=1, right_count=3
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.004524886877828055, feature_index=1, left_count=2, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [1/20] node_type=right_node, cost=2097.272926382459, feature_index=2, left_count=116, right_count=108
# [1/20] grow_left=True, grow_right=True
# [2/20] node_type=left_node, cost=981.8996037084273, feature_index=2, left_count=42, right_count=74
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=222.74849170437403, feature_index=4, left_count=6, right_count=36
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=16.553544494720967, feature_index=5, left_count=3, right_count=3
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=0.05542986425339367, feature_index=2, left_count=2, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=2, left_count=2, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=163.66923076923075, feature_index=9, left_count=30, right_count=6
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=124.37908496732025, feature_index=8, left_count=21, right_count=9
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=58.49337427278603, feature_index=2, left_count=7, right_count=14
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=18.332126696832578, feature_index=6, left_count=2, right_count=5
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.47322775263951733, feature_index=6, left_count=3, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.010180995475113122, feature_index=1, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=18.897220426632195, feature_index=5, left_count=7, right_count=7
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=2.758371040723982, feature_index=8, left_count=5, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.8506787330316743, feature_index=6, left_count=2, right_count=3
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.07239819004524888, feature_index=2, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=5.506033182503771, feature_index=5, left_count=3, right_count=4
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=1.0180995475113124, feature_index=4, left_count=1, right_count=2
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.37254901960784315, feature_index=2, left_count=3, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.05542986425339367, feature_index=3, left_count=1, right_count=2
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=15.718164188752423, feature_index=6, left_count=7, right_count=2
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=5.527828054298642, feature_index=8, left_count=5, right_count=2
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.5094268476621417, feature_index=2, left_count=3, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.09162895927601811, feature_index=2, left_count=1, right_count=2
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=2.083257918552036, feature_index=8, left_count=5, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=0.5625942684766214, feature_index=2, left_count=3, right_count=2
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=635.8776619622208, feature_index=8, left_count=18, right_count=56
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=81.30066132962061, feature_index=6, left_count=5, right_count=13
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=14.70739064856712, feature_index=4, left_count=2, right_count=3
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.49886877828054305, feature_index=2, left_count=2, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=15.91009480715363, feature_index=9, left_count=6, right_count=7
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=4.173076923076923, feature_index=6, left_count=2, right_count=4
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.12669683257918554, feature_index=2, left_count=3, right_count=1
# [7/20] grow_left=True, grow_right=False
# [8/20] node_type=left_node, cost=0.004524886877828055, feature_index=2, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=1.737556561085973, feature_index=3, left_count=6, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.5904977375565611, feature_index=8, left_count=2, right_count=4
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.09502262443438914, feature_index=1, left_count=1, right_count=3
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.010180995475113122, feature_index=2, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=392.4433741571487, feature_index=9, left_count=43, right_count=13
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=257.84913126089594, feature_index=9, left_count=21, right_count=22
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=91.2030234471411, feature_index=8, left_count=11, right_count=10
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=20.73303167420815, feature_index=3, left_count=8, right_count=3
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=6.013574660633484, feature_index=4, left_count=2, right_count=6
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.5910633484162896, feature_index=2, left_count=4, right_count=2
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.04638009049773756, feature_index=3, left_count=2, right_count=2
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=14.555268261150614, feature_index=4, left_count=3, right_count=7
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.2895927601809955, feature_index=2, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=4.510633484162896, feature_index=9, left_count=2, right_count=5
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.3484162895927602, feature_index=1, left_count=1, right_count=4
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.04675716440422323, feature_index=4, left_count=1, right_count=3
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.0011312217194570137, feature_index=3, left_count=1, right_count=2
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=106.27149321266967, feature_index=7, left_count=20, right_count=2
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=77.67058823529412, feature_index=4, left_count=15, right_count=5
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=24.932692307692307, feature_index=4, left_count=12, right_count=3
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=13.23099547511312, feature_index=1, left_count=2, right_count=10
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=6.209841628959277, feature_index=8, left_count=4, right_count=6
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.5625942684766215, feature_index=4, left_count=1, right_count=3
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.01809954751131222, feature_index=2, left_count=2, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.785633484162896, feature_index=3, left_count=2, right_count=4
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.05090497737556561, feature_index=2, left_count=2, right_count=2
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [13/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.36651583710407243, feature_index=3, left_count=1, right_count=2
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=1.2503770739064857, feature_index=5, left_count=2, right_count=3
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0011312217194570137, feature_index=2, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=53.395475113122174, feature_index=3, left_count=5, right_count=8
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=5.665158371040724, feature_index=4, left_count=2, right_count=3
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.40837104072398195, feature_index=2, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# ...
# [8/20] node_type=left_node, cost=0.3770739064856712, feature_index=2, left_count=3, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [2/20] node_type=right_node, cost=840.5301832891967, feature_index=2, left_count=77, right_count=31
# [2/20] grow_left=True, grow_right=True
# [3/20] node_type=left_node, cost=570.505433292198, feature_index=3, left_count=33, right_count=44
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=304.67390648567124, feature_index=9, left_count=30, right_count=3
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=254.5863768584357, feature_index=6, left_count=2, right_count=28
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=198.7029706866024, feature_index=8, left_count=23, right_count=5
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=116.18051917123125, feature_index=2, left_count=4, right_count=19
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=5.413273001508296, feature_index=4, left_count=3, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.5984162895927603, feature_index=1, left_count=2, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=63.2134776987718, feature_index=4, left_count=5, right_count=14
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=2.635746606334842, feature_index=4, left_count=1, right_count=4
# [9/20] grow_left=False, grow_right=True
# [10/20] node_type=right_node, cost=0.5173453996983409, feature_index=4, left_count=1, right_count=3
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=0.05542986425339367, feature_index=3, left_count=2, right_count=1
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=29.864724736048267, feature_index=7, left_count=8, right_count=6
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=5.422699849170438, feature_index=3, left_count=6, right_count=2
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.9971719457013575, feature_index=2, left_count=2, right_count=4
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.058823529411764705, feature_index=4, left_count=3, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.004524886877828055, feature_index=4, left_count=2, right_count=1
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [14/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=6.523190045248869, feature_index=4, left_count=2, right_count=4
# [10/20] grow_left=True, grow_right=True
# [11/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [11/20] grow_left=False, grow_right=False
# [11/20] node_type=right_node, cost=0.2907239819004525, feature_index=1, left_count=2, right_count=2
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [12/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=12.29110105580694, feature_index=2, left_count=3, right_count=2
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.5486425339366516, feature_index=2, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=0.0, feature_index=3, left_count=1, right_count=2
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=161.62965057817996, feature_index=8, left_count=36, right_count=8
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=120.58286199095024, feature_index=3, left_count=32, right_count=4
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=104.45446107437058, feature_index=9, left_count=6, right_count=26
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=1.3642533936651584, feature_index=6, left_count=4, right_count=2
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.18099547511312217, feature_index=1, left_count=2, right_count=2
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=87.02393599580299, feature_index=2, left_count=3, right_count=23
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=1.3076923076923077, feature_index=2, left_count=1, right_count=2
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=71.83021390374333, feature_index=9, left_count=22, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=62.969645550527915, feature_index=9, left_count=16, right_count=6
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=39.97948717948718, feature_index=5, left_count=1, right_count=15
# [10/20] grow_left=False, grow_right=True
# [11/20] node_type=right_node, cost=26.549490950226247, feature_index=5, left_count=7, right_count=8
# [11/20] grow_left=True, grow_right=True
# [12/20] node_type=left_node, cost=3.0245098039215685, feature_index=2, left_count=6, right_count=1
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=1.2126696832579185, feature_index=4, left_count=5, right_count=1
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.1917420814479638, feature_index=2, left_count=1, right_count=4
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.05429864253393665, feature_index=3, left_count=3, right_count=1
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=4, left_count=1, right_count=2
# [16/20] grow_left=False, grow_right=True
# [17/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [17/20] grow_left=False, grow_right=False
# [12/20] node_type=right_node, cost=7.7007918552036205, feature_index=4, left_count=4, right_count=4
# [12/20] grow_left=True, grow_right=True
# [13/20] node_type=left_node, cost=1.431372549019608, feature_index=2, left_count=3, right_count=1
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.028280542986425343, feature_index=2, left_count=1, right_count=2
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [15/20] grow_left=False, grow_right=False
# [13/20] node_type=right_node, cost=0.6892911010558068, feature_index=5, left_count=1, right_count=3
# [13/20] grow_left=False, grow_right=True
# [14/20] node_type=right_node, cost=0.05542986425339367, feature_index=3, left_count=1, right_count=2
# [14/20] grow_left=False, grow_right=True
# [15/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [15/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=2.995475113122172, feature_index=2, left_count=5, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.7782805429864255, feature_index=2, left_count=1, right_count=4
# [11/20] grow_left=False, grow_right=True
# [12/20] node_type=right_node, cost=0.1870286576168929, feature_index=3, left_count=1, right_count=3
# [12/20] grow_left=False, grow_right=True
# [13/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=2, right_count=1
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [14/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.7782805429864253, feature_index=1, left_count=3, right_count=1
# [6/20] grow_left=True, grow_right=False
# [7/20] node_type=left_node, cost=0.11312217194570137, feature_index=2, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=5.780995475113121, feature_index=6, left_count=5, right_count=3
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=1.1063348416289593, feature_index=2, left_count=1, right_count=4
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.20135746606334842, feature_index=3, left_count=2, right_count=2
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.05542986425339367, feature_index=2, left_count=1, right_count=2
# [6/20] grow_left=False, grow_right=True
# [7/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [3/20] node_type=right_node, cost=98.02914384377232, feature_index=5, left_count=19, right_count=12
# [3/20] grow_left=True, grow_right=True
# [4/20] node_type=left_node, cost=29.927090066795948, feature_index=8, left_count=7, right_count=12
# [4/20] grow_left=True, grow_right=True
# [5/20] node_type=left_node, cost=1.0119909502262443, feature_index=6, left_count=5, right_count=2
# [5/20] grow_left=True, grow_right=True
# [6/20] node_type=left_node, cost=0.25, feature_index=2, left_count=2, right_count=3
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.028280542986425343, feature_index=1, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [6/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [6/20] grow_left=False, grow_right=False
# [5/20] node_type=right_node, cost=6.476347182229536, feature_index=7, left_count=11, right_count=1
# [5/20] grow_left=True, grow_right=False
# [6/20] node_type=left_node, cost=1.2356711915535445, feature_index=5, left_count=8, right_count=3
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.6998491704374056, feature_index=9, left_count=2, right_count=6
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.08880090497737558, feature_index=5, left_count=2, right_count=4
# [8/20] grow_left=True, grow_right=True
# [9/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
# [9/20] node_type=right_node, cost=0.006033182503770739, feature_index=2, left_count=3, right_count=1
# [9/20] grow_left=True, grow_right=False
# [10/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=1
# [10/20] grow_left=True, grow_right=False
# [11/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [11/20] grow_left=True, grow_right=False
# [12/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [12/20] grow_left=True, grow_right=False
# [13/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [13/20] grow_left=True, grow_right=False
# [14/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [14/20] grow_left=True, grow_right=False
# [15/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [15/20] grow_left=True, grow_right=False
# [16/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [16/20] grow_left=True, grow_right=False
# [17/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [17/20] grow_left=True, grow_right=False
# [18/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [18/20] grow_left=True, grow_right=False
# [19/20] node_type=left_node, cost=0.0, feature_index=1, left_count=2, right_count=0
# [19/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=0.004524886877828055, feature_index=2, left_count=1, right_count=2
# [7/20] grow_left=False, grow_right=True
# [8/20] node_type=right_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [8/20] grow_left=False, grow_right=False
# [4/20] node_type=right_node, cost=23.75277663512957, feature_index=4, left_count=1, right_count=11
# [4/20] grow_left=False, grow_right=True
# [5/20] node_type=right_node, cost=14.32601809954751, feature_index=6, left_count=1, right_count=10
# [5/20] grow_left=False, grow_right=True
# [6/20] node_type=right_node, cost=8.091628959276019, feature_index=4, left_count=2, right_count=8
# [6/20] grow_left=True, grow_right=True
# [7/20] node_type=left_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [7/20] grow_left=False, grow_right=False
# [7/20] node_type=right_node, cost=3.916742081447964, feature_index=9, left_count=5, right_count=3
# [7/20] grow_left=True, grow_right=True
# [8/20] node_type=left_node, cost=0.14649321266968326, feature_index=2, left_count=1, right_count=4
# [8/20] grow_left=False, grow_right=True
# [9/20] node_type=right_node, cost=0.019230769230769232, feature_index=6, left_count=2, right_count=2
# [9/20] grow_left=True, grow_right=True
# [10/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [10/20] node_type=right_node, cost=0.0, feature_index=1, left_count=1, right_count=1
# [10/20] grow_left=False, grow_right=False
# [8/20] node_type=right_node, cost=0.1911764705882353, feature_index=3, left_count=2, right_count=1
# [8/20] grow_left=True, grow_right=False
# [9/20] node_type=left_node, cost=0.0, feature_index=2, left_count=1, right_count=1
# [9/20] grow_left=False, grow_right=False
