# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_diabetes
from pydantic import BaseModel
from typing import Optional

class SplitData(BaseModel):
     left_indices: np.array
     right_indices: np.array
     feat_index: np.int32
     cost: np.float32
     thresh: np.float32
     

class TreeNode:
    def __init__(self, 
                 X : np.array, 
                 y : np.array,
                 split_data
                 depth, max_depth, 
                 max_leaves):
        self.depth = depth
        
        self.max_depth = max_depth 
        self.max_leaves = self.max_leaves

        if self.max_depth > self.depth + 1:
            self.left_node = TreeNode()

    
    def split_by_min_thresh(self, X, y, feat_index):
        thresh = np.unique(X[:,feat_index]).reshape(1,-1)
        selected_feat = X[:,feat_index].reshape(-1,1)
        is_left_sampler = (selected_feat <= thresh)
        stacked_targets = np.hstack([y.reshape(-1,1)] * is_left_sampler.shape[1])
        left_sampled, right_sampled = is_left_sampler * stacked_targets, (~is_left_sampler) * stacked_targets

        n_samples_left, n_samples_right = np.sum(is_left_sampler, axis=0), np.sum(~is_left_sampler, axis=0)

        with np.errstate(divide='ignore', invalid='ignore'):
            left_samples_mean = np.where(n_samples_left == 0, 0, np.sum(left_sampled, axis=0) / n_samples_left)
            right_samples_mean = np.where(n_samples_right == 0, 0, np.sum(right_sampled, axis=0) / n_samples_right)
        
        var_left = is_left_sampler * (left_sampled - left_samples_mean.reshape(1,-1)) ** 2
        var_right = (~is_left_sampler) * (right_sampled - right_samples_mean.reshape(1,-1)) ** 2

        with np.errstate(divide='ignore', invalid='ignore'):
            var_left = np.where(n_samples_left == 0, 0, np.sum(var_left, axis=0) / n_samples_left)
            var_right = np.where(n_samples_right == 0, 0, np.sum(var_right, axis=0) / n_samples_right)

        total_samples = left_sampled.shape[0]
        assert total_samples == right_sampled.shape[0], 'wrong total samples'

        ratio_left, ratio_right = n_samples_left / total_samples, n_samples_right / total_samples
        thresh_cost = ratio_left * var_left + ratio_right * var_right
        min_thresh_index = np.argmin(thresh_cost)

        return SplitData(
            left_indices=np.nonzero(is_left_sampler[:, min_thresh_index])[0],
            right_indices=np.nonzero(~is_left_sampler[:, min_thresh_index])[0],
            feat_index=feat_index,
            cost=np.min(thresh_cost),
            thresh = thresh.reshape(-1)[min_thresh_index],
        ) 

    def split_by_min_feat_thresh(self, X, y):
        feat_count = X.shape[1]
        min_split_data = self.split_by_min_thresh(X, y, 0)

        for feat_index in range(1, feat_count):
            split_data = self.split_by_min_thresh(X, y, feat_index)
            if min_split_data.cost > split_data.cost:
                min_split_data = split_data

        return min_split_data
# Out:
# ---------------------------------------------------------------------------
# PydanticSchemaGenerationError             Traceback (most recent call last)
# Cell In[1], line 7
#       4 from pydantic import BaseModel
#       5 from typing import Optional
# ----> 7 class SplitData(BaseModel):
#       8      left_indices: np.array
#       9      right_indices: np.array
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py:183, in ModelMetaclass.__new__(mcs, cls_name, bases, namespace, __pydantic_generic_metadata__, __pydantic_reset_parent_namespace__, _create_model_module, **kwargs)
#     180 if config_wrapper.frozen and '__hash__' not in namespace:
#     181     set_default_hash_func(cls, bases)
# --> 183 complete_model_class(
#     184     cls,
#     185     cls_name,
#     186     config_wrapper,
#     187     raise_errors=False,
#     188     types_namespace=types_namespace,
#     189     create_model_module=_create_model_module,
#     190 )
#     192 # If this is placed before the complete_model_class call above,
#     193 # the generic computed fields return type is set to PydanticUndefined
#     194 cls.model_computed_fields = {k: v.info for k, v in cls.__pydantic_decorators__.computed_fields.items()}
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_model_construction.py:517, in complete_model_class(cls, cls_name, config_wrapper, raise_errors, types_namespace, create_model_module)
#     514     return False
#     516 try:
# --> 517     schema = cls.__get_pydantic_core_schema__(cls, handler)
#     518 except PydanticUndefinedAnnotation as e:
#     519     if raise_errors:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/main.py:584, in BaseModel.__get_pydantic_core_schema__(cls, _BaseModel__source, _BaseModel__handler)
#     581     if not cls.__pydantic_generic_metadata__['origin']:
#     582         return cls.__pydantic_core_schema__
# --> 584 return __handler(__source)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_schema_generation_shared.py:82, in CallbackGetCoreSchemaHandler.__call__(self, _CallbackGetCoreSchemaHandler__source_type)
#      81 def __call__(self, __source_type: Any) -> core_schema.CoreSchema:
# ---> 82     schema = self._handler(__source_type)
#      83     ref = schema.get('ref')
#      84     if self._ref_mode == 'to-def':
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:499, in GenerateSchema.generate_schema(self, obj, from_dunder_get_core_schema)
#     496         schema = from_property
#     498 if schema is None:
# --> 499     schema = self._generate_schema(obj)
#     501 metadata_js_function = _extract_get_pydantic_json_schema(obj, schema)
#     502 if metadata_js_function is not None:
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:737, in GenerateSchema._generate_schema(self, obj)
#     735 needs_apply_discriminated_union = self._needs_apply_discriminated_union
#     736 self._needs_apply_discriminated_union = False
# --> 737 schema = self._post_process_generated_schema(self._generate_schema_inner(obj))
#     738 self._has_invalid_schema = self._has_invalid_schema or has_invalid_schema
#     739 self._needs_apply_discriminated_union = self._needs_apply_discriminated_union or needs_apply_discriminated_union
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:759, in GenerateSchema._generate_schema_inner(self, obj)
#     756 from ..main import BaseModel
#     758 if lenient_issubclass(obj, BaseModel):
# --> 759     return self._model_schema(obj)
#     761 if isinstance(obj, PydanticRecursiveRef):
#     762     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:572, in GenerateSchema._model_schema(self, cls)
#     560     model_schema = core_schema.model_schema(
#     561         cls,
#     562         inner_schema,
#    (...)
#     568         metadata=metadata,
#     569     )
#     570 else:
#     571     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 572         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     573         computed_fields=[
#     574             self._computed_field_schema(d, decorators.field_serializers)
#     575             for d in computed_fields.values()
#     576         ],
#     577         extras_schema=extras_schema,
#     578         model_name=cls.__name__,
#     579     )
#     580     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     581     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:572, in <dictcomp>(.0)
#     560     model_schema = core_schema.model_schema(
#     561         cls,
#     562         inner_schema,
#    (...)
#     568         metadata=metadata,
#     569     )
#     570 else:
#     571     fields_schema: core_schema.CoreSchema = core_schema.model_fields_schema(
# --> 572         {k: self._generate_md_field_schema(k, v, decorators) for k, v in fields.items()},
#     573         computed_fields=[
#     574             self._computed_field_schema(d, decorators.field_serializers)
#     575             for d in computed_fields.values()
#     576         ],
#     577         extras_schema=extras_schema,
#     578         model_name=cls.__name__,
#     579     )
#     580     inner_schema = apply_validators(fields_schema, decorators.root_validators.values(), None)
#     581     new_inner_schema = define_expected_missing_refs(inner_schema, recursively_defined_type_refs())
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:923, in GenerateSchema._generate_md_field_schema(self, name, field_info, decorators)
#     916 def _generate_md_field_schema(
#     917     self,
#     918     name: str,
#     919     field_info: FieldInfo,
#     920     decorators: DecoratorInfos,
#     921 ) -> core_schema.ModelField:
#     922     """Prepare a ModelField to represent a model field."""
# --> 923     common_field = self._common_field_schema(name, field_info, decorators)
#     924     return core_schema.model_field(
#     925         common_field['schema'],
#     926         serialization_exclude=common_field['serialization_exclude'],
#    (...)
#     930         metadata=common_field['metadata'],
#     931     )
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1045, in GenerateSchema._common_field_schema(self, name, field_info, decorators)
#    1043         schema = self._apply_annotations(source_type, annotations, transform_inner_schema=set_discriminator)
#    1044     else:
# -> 1045         schema = self._apply_annotations(
#    1046             source_type,
#    1047             annotations,
#    1048         )
#    1050 # This V1 compatibility shim should eventually be removed
#    1051 # push down any `each_item=True` validators
#    1052 # note that this won't work for any Annotated types that get wrapped by a function validator
#    1053 # but that's okay because that didn't exist in V1
#    1054 this_field_validators = filter_field_decorator_info_by_field(decorators.validators.values(), name)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1747, in GenerateSchema._apply_annotations(self, source_type, annotations, transform_inner_schema)
#    1742         continue
#    1743     get_inner_schema = self._get_wrapped_inner_schema(
#    1744         get_inner_schema, annotation, pydantic_js_annotation_functions
#    1745     )
# -> 1747 schema = get_inner_schema(source_type)
#    1748 if pydantic_js_annotation_functions:
#    1749     metadata = CoreMetadataHandler(schema).metadata
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_schema_generation_shared.py:82, in CallbackGetCoreSchemaHandler.__call__(self, _CallbackGetCoreSchemaHandler__source_type)
#      81 def __call__(self, __source_type: Any) -> core_schema.CoreSchema:
# ---> 82     schema = self._handler(__source_type)
#      83     ref = schema.get('ref')
#      84     if self._ref_mode == 'to-def':
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:1728, in GenerateSchema._apply_annotations.<locals>.inner_handler(obj)
#    1726 from_property = self._generate_schema_from_property(obj, obj)
#    1727 if from_property is None:
# -> 1728     schema = self._generate_schema(obj)
#    1729 else:
#    1730     schema = from_property
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:737, in GenerateSchema._generate_schema(self, obj)
#     735 needs_apply_discriminated_union = self._needs_apply_discriminated_union
#     736 self._needs_apply_discriminated_union = False
# --> 737 schema = self._post_process_generated_schema(self._generate_schema_inner(obj))
#     738 self._has_invalid_schema = self._has_invalid_schema or has_invalid_schema
#     739 self._needs_apply_discriminated_union = self._needs_apply_discriminated_union or needs_apply_discriminated_union
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:764, in GenerateSchema._generate_schema_inner(self, obj)
#     761 if isinstance(obj, PydanticRecursiveRef):
#     762     return core_schema.definition_reference_schema(schema_ref=obj.type_ref)
# --> 764 return self.match_type(obj)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:851, in GenerateSchema.match_type(self, obj)
#     849 if self._arbitrary_types:
#     850     return self._arbitrary_type_schema(obj)
# --> 851 return self._unknown_type_schema(obj)
#
# File ~/miniconda3/envs/ml/lib/python3.11/site-packages/pydantic/_internal/_generate_schema.py:397, in GenerateSchema._unknown_type_schema(self, obj)
#     396 def _unknown_type_schema(self, obj: Any) -> CoreSchema:
# --> 397     raise PydanticSchemaGenerationError(
#     398         f'Unable to generate pydantic-core schema for {obj!r}. '
#     399         'Set `arbitrary_types_allowed=True` in the model_config to ignore this error'
#     400         ' or implement `__get_pydantic_core_schema__` on your type to fully support it.'
#     401         '\n\nIf you got this error by calling handler(<some type>) within'
#     402         ' `__get_pydantic_core_schema__` then you likely need to call'
#     403         ' `handler.generate_schema(<some type>)` since we do not call'
#     404         ' `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.'
#     405     )
#
# PydanticSchemaGenerationError: Unable to generate pydantic-core schema for <built-in function array>. Set `arbitrary_types_allowed=True` in the model_config to ignore this error or implement `__get_pydantic_core_schema__` on your type to fully support it.
#
# If you got this error by calling handler(<some type>) within `__get_pydantic_core_schema__` then you likely need to call `handler.generate_schema(<some type>)` since we do not call `__get_pydantic_core_schema__` on `<some type>` otherwise to avoid infinite recursion.
#
# For further information visit https://errors.pydantic.dev/2.6/u/schema-for-unknown-type
